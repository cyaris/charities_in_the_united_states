# %% [markdown]
# # **Linear Models with US Charities**
# ### **Data obtained from charitynavigator.org**

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('charity_navigator_clean.csv', index_col = 0)

# %% [markdown]
# Create a dataframe with no null values.

# %%
df[df['comp_leader_income'].isnull() == False].reset_index(drop=True)
# Out:
#       accountability_score  administrative_expenses  \
# 0                     89.0                 164590.0
# 1                     86.0                1001560.0
# 2                     85.0                  93957.0
# 3                     86.0                 346867.0
# 4                     97.0                 135195.0
# 5                    100.0                 505751.0
# 6                     89.0                 103173.0
# 7                    100.0                 663845.0
# 8                    100.0                  77155.0
# 9                     89.0                 200643.0
# 10                    93.0                 611779.0
# 11                    89.0                 359125.0
# 12                    89.0                 168553.0
# 13                   100.0                 940855.0
# 14                   100.0                 119743.0
# 15                    89.0                  83378.0
# 16                    89.0                 548733.0
# 17                    81.0                 204621.0
# 18                    93.0               18026507.0
# 19                   100.0                 336234.0
# 20                    96.0                 385923.0
# 21                   100.0                 838660.0
# 22                    82.0                 416919.0
# 23                   100.0                 124005.0
# 24                    96.0                  77735.0
# 25                   100.0                 552261.0
# 26                   100.0                 163132.0
# 27                    89.0                 201970.0
# 28                   100.0                1418750.0
# 29                   100.0                1337698.0
# ...                    ...                      ...
# 7260                  89.0                2367795.0
# 7261                 100.0                 335972.0
# 7262                  89.0                 160427.0
# 7263                 100.0                  33429.0
# 7264                  88.0                 439051.0
# 7265                  96.0                1530836.0
# 7266                  89.0                 271021.0
# 7267                  89.0                 345674.0
# 7268                  96.0                 349389.0
# 7269                  85.0                 648131.0
# 7270                  96.0                 782422.0
# 7271                  96.0                 165066.0
# 7272                 100.0                 281504.0
# 7273                 100.0                 166222.0
# 7274                  89.0                1653619.0
# 7275                  89.0                1153074.0
# 7276                  92.0                 166468.0
# 7277                  73.0                 105457.0
# 7278                  80.0                 338719.0
# 7279                  89.0                 335447.0
# 7280                  96.0                 450058.0
# 7281                  92.0                 161957.0
# 7282                  89.0                 344156.0
# 7283                  89.0                 270466.0
# 7284                  85.0                 654487.0
# 7285                 100.0                 207403.0
# 7286                  92.0                3340102.0
# 7287                  89.0                 457456.0
# 7288                  96.0                3114784.0
# 7289                 100.0                 350661.0
#
#                                            charity_name  \
# 0            9to5 National Association of Working Women
# 1                                       'Aha Pūnana Leo
# 2                            AID FOR AIDS International
# 3                                  Futures in Education
# 4                           Every Generation Ministries
# 5                              Futures Without Violence
# 6                         Gwinnett Habitat for Humanity
# 7                        Izaak Walton League of America
# 8                                It's The Journey, Inc.
# 9                           Issaquah Schools Foundation
# 10                            Hydrocephalus Association
# 11                                  The Hyde Collection
# 12                        Huntsville Symphony Orchestra
# 13              Huntington's Disease Society of America
# 14                        Huron River Watershed Council
# 15                       Byrnes Health Education Center
# 16                          Huntsville Botanical Garden
# 17                             Huntsville Museum of Art
# 18                           Cystic Fibrosis Foundation
# 19                                             Cure SMA
# 20                                              CurePSP
# 21                                   CURE International
# 22                                    Dégagé Ministries
# 23                                       dZi Foundation
# 24    Dystrophic Epidermolysis Bullosa Research Asso...
# 25                                          CuriOdyssey
# 26                 Dystonia Medical Research Foundation
# 27                                        24 Foundation
# 28                                  Dumb Friends League
# 29                                Durham Rescue Mission
# ...                                                 ...
# 7260            Lankenau Institute for Medical Research
# 7261                                Langham Partnership
# 7262                            Landmark on Main Street
# 7263                            Last Chance for Animals
# 7264                            Laumeier Sculpture Park
# 7265                                            Landesa
# 7266                           Land Stewardship Project
# 7267                                        LAND studio
# 7268                                 The Land Institute
# 7269                               LancasterHistory.org
# 7270                                Land Trust Alliance
# 7271                                    The Lamb Center
# 7272                             Lamb & Lion Ministries
# 7273                                 The LAM Foundation
# 7274                       Larkin Street Youth Services
# 7275                                  Lauritzen Gardens
# 7276                     Lakeshore Habitat for Humanity
# 7277                    Lakeland Volunteers in Medicine
# 7278                         Lakeland Public Television
# 7279                                      Laura's House
# 7280                               Lake Area United Way
# 7281                  Lake Erie Nature & Science Center
# 7282                                    Lakeview Pantry
# 7283                                      Lackey Clinic
# 7284                                The Labouré Society
# 7285                                    LA Promise Fund
# 7286                                           LA Opera
# 7287                             La Jolla Music Society
# 7288                                 La Jolla Playhouse
# 7289                         La Comunidad Hispana (LCH)
#
#                                             charity_url               city  \
# 0     https://www.charitynavigator.org/index.cfm?bay...          Milwaukee
# 1     https://www.charitynavigator.org/index.cfm?bay...               Hilo
# 2     https://www.charitynavigator.org/index.cfm?bay...           New York
# 3     https://www.charitynavigator.org/index.cfm?bay...           Brooklyn
# 4     https://www.charitynavigator.org/index.cfm?bay...           Temecula
# 5     https://www.charitynavigator.org/index.cfm?bay...      San Francisco
# 6     https://www.charitynavigator.org/index.cfm?bay...     Stone Mountain
# 7     https://www.charitynavigator.org/index.cfm?bay...       Gaithersburg
# 8     https://www.charitynavigator.org/index.cfm?bay...            Atlanta
# 9     https://www.charitynavigator.org/index.cfm?bay...           Bellevue
# 10    https://www.charitynavigator.org/index.cfm?bay...           Bethesda
# 11    https://www.charitynavigator.org/index.cfm?bay...        Glens Falls
# 12    https://www.charitynavigator.org/index.cfm?bay...         Huntsville
# 13    https://www.charitynavigator.org/index.cfm?bay...           New York
# 14    https://www.charitynavigator.org/index.cfm?bay...          Ann Arbor
# 15    https://www.charitynavigator.org/index.cfm?bay...               York
# 16    https://www.charitynavigator.org/index.cfm?bay...         Huntsville
# 17    https://www.charitynavigator.org/index.cfm?bay...         Huntsville
# 18    https://www.charitynavigator.org/index.cfm?bay...           Bethesda
# 19    https://www.charitynavigator.org/index.cfm?bay...  Elk Grove Village
# 20    https://www.charitynavigator.org/index.cfm?bay...           New York
# 21    https://www.charitynavigator.org/index.cfm?bay...     New Cumberland
# 22    https://www.charitynavigator.org/index.cfm?bay...       Grand Rapids
# 23    https://www.charitynavigator.org/index.cfm?bay...            Ridgway
# 24    https://www.charitynavigator.org/index.cfm?bay...           New York
# 25    https://www.charitynavigator.org/index.cfm?bay...          San Mateo
# 26    https://www.charitynavigator.org/index.cfm?bay...            Chicago
# 27    https://www.charitynavigator.org/index.cfm?bay...          Charlotte
# 28    https://www.charitynavigator.org/index.cfm?bay...             Denver
# 29    https://www.charitynavigator.org/index.cfm?bay...             Durham
# ...                                                 ...                ...
# 7260  https://www.charitynavigator.org/index.cfm?bay...          Wynnewood
# 7261  https://www.charitynavigator.org/index.cfm?bay...         Cave Creek
# 7262  https://www.charitynavigator.org/index.cfm?bay...    Port Washington
# 7263  https://www.charitynavigator.org/index.cfm?bay...        Los Angeles
# 7264  https://www.charitynavigator.org/index.cfm?bay...          St. Louis
# 7265  https://www.charitynavigator.org/index.cfm?bay...            Seattle
# 7266  https://www.charitynavigator.org/index.cfm?bay...        Minneapolis
# 7267  https://www.charitynavigator.org/index.cfm?bay...          Cleveland
# 7268  https://www.charitynavigator.org/index.cfm?bay...             Salina
# 7269  https://www.charitynavigator.org/index.cfm?bay...          Lancaster
# 7270  https://www.charitynavigator.org/index.cfm?bay...         Washington
# 7271  https://www.charitynavigator.org/index.cfm?bay...            Fairfax
# 7272  https://www.charitynavigator.org/index.cfm?bay...           McKinney
# 7273  https://www.charitynavigator.org/index.cfm?bay...         Cincinnati
# 7274  https://www.charitynavigator.org/index.cfm?bay...      San Francisco
# 7275  https://www.charitynavigator.org/index.cfm?bay...              Omaha
# 7276  https://www.charitynavigator.org/index.cfm?bay...            Holland
# 7277  https://www.charitynavigator.org/index.cfm?bay...           Lakeland
# 7278  https://www.charitynavigator.org/index.cfm?bay...            Bemidji
# 7279  https://www.charitynavigator.org/index.cfm?bay...       Ladera Ranch
# 7280  https://www.charitynavigator.org/index.cfm?bay...           Griffith
# 7281  https://www.charitynavigator.org/index.cfm?bay...        Bay Village
# 7282  https://www.charitynavigator.org/index.cfm?bay...            Chicago
# 7283  https://www.charitynavigator.org/index.cfm?bay...           Yorktown
# 7284  https://www.charitynavigator.org/index.cfm?bay...              Eagan
# 7285  https://www.charitynavigator.org/index.cfm?bay...        Los Angeles
# 7286  https://www.charitynavigator.org/index.cfm?bay...        Los Angeles
# 7287  https://www.charitynavigator.org/index.cfm?bay...           La Jolla
# 7288  https://www.charitynavigator.org/index.cfm?bay...           La Jolla
# 7289  https://www.charitynavigator.org/index.cfm?bay...     Kennett Square
#
#      cn_advisory  comp_leader_income  comp_leader_expense_pct  \
# 0            NaN             53463.0                     3.11
# 1            NaN             73500.0                     1.47
# 2            NaN             85000.0                     0.99
# 3            NaN             61220.0                     0.78
# 4            NaN             74244.0                     5.41
# 5            NaN            312498.0                     2.85
# 6            NaN             85665.0                     7.27
# 7            NaN            154999.0                     6.01
# 8            NaN            110110.0                     7.36
# 9            NaN             98048.0                     5.89
# 10           NaN            200000.0                     5.02
# 11           NaN             73138.0                     4.14
# 12           NaN             82500.0                     4.51
# 13           NaN            264026.0                     3.28
# 14           NaN            104945.0                     6.73
# 15           NaN             89280.0                     7.86
# 16           NaN            151680.0                     4.51
# 17           NaN            150988.0                     6.53
# 18           NaN            496970.0                     0.19
# 19           NaN            182099.0                     2.40
# 20           NaN            193846.0                     6.14
# 21           NaN            168480.0                     0.24
# 22           NaN             72079.0                     3.89
# 23           NaN             77762.0                     6.09
# 24           NaN            153012.0                     9.46
# 25           NaN            147578.0                     3.37
# 26           NaN            144894.0                     5.86
# 27           NaN             69731.0                     2.25
# 28           NaN            302320.0                     1.64
# 29           NaN            148024.0                     0.71
# ...          ...                 ...                      ...
# 7260         NaN            395598.0                     2.63
# 7261         NaN            154654.0                     4.34
# 7262         NaN             79000.0                     5.43
# 7263         NaN            110000.0                     5.37
# 7264         NaN            125000.0                     6.75
# 7265         NaN             93089.0                     0.79
# 7266         NaN             73288.0                     2.76
# 7267         NaN            137563.0                     1.09
# 7268         NaN             92000.0                     2.53
# 7269         NaN            152338.0                     6.63
# 7270         NaN            249591.0                     1.70
# 7271         NaN             96067.0                     9.36
# 7272         NaN             75236.0                     2.46
# 7273         NaN            125060.0                     8.44
# 7274         NaN            173263.0                     1.00
# 7275         NaN            220254.0                     3.59
# 7276         NaN             67155.0                     2.83
# 7277         NaN             89896.0                     5.87
# 7278         NaN            106110.0                     3.66
# 7279         NaN            233616.0                     6.96
# 7280         NaN            130551.0                     2.85
# 7281         NaN            112500.0                     7.18
# 7282         NaN            122828.0                     2.66
# 7283         NaN             80253.0                     0.98
# 7284         NaN             93332.0                     3.07
# 7285         NaN            193020.0                     6.36
# 7286         NaN            528245.0                     1.31
# 7287         NaN             65766.0                     1.46
# 7288         NaN            310591.0                     1.90
# 7289         NaN            114557.0                     2.73
#
#               comp_leader_title  excess_or_deficit_for_year     ...      \
# 0            Executive Director                    349718.0     ...
# 1            Executive Director                   1175965.0     ...
# 2            Executive Director                   -461502.0     ...
# 3     Acting Executive Director                   1872733.0     ...
# 4                     President                   -103940.0     ...
# 5           President & Founder                   1931497.0     ...
# 6            Executive Director                   -126216.0     ...
# 7            Executive Director                   -294094.0     ...
# 8            Executive Director                    107849.0     ...
# 9            Executive Director                    -59227.0     ...
# 10                          CEO                    714966.0     ...
# 11                     Director                   2131553.0     ...
# 12               President, CEO                     -3753.0     ...
# 13      Chief Executive Officer                    537310.0     ...
# 14           Executive Director                     29518.0     ...
# 15               President, CEO                    -22834.0     ...
# 16                          CEO                   7440415.0     ...
# 17           Executive Director                     66429.0     ...
# 18               President, CEO                 -44527665.0     ...
# 19                    President                    307259.0     ...
# 20                    President                     71600.0     ...
# 21               President, CEO                 -14162177.0     ...
# 22           Executive Director                    -27245.0     ...
# 23                    President                    166629.0     ...
# 24           Executive Director                     -8398.0     ...
# 25           Executive Director                   2682302.0     ...
# 26           Executive Director                   2655471.0     ...
# 27           Executive Director                   -928932.0     ...
# 28                    President                  -1551599.0     ...
# 29      Chief Executive Officer                  -8027987.0     ...
# ...                         ...                         ...     ...
# 7260                  President                  -6148341.0     ...
# 7261                  President                   -158671.0     ...
# 7262         Executive Director                     14252.0     ...
# 7263                  President                    393646.0     ...
# 7264         Executive Director                   -143839.0     ...
# 7265             President, CEO                   3302601.0     ...
# 7266         Executive Director                    962589.0     ...
# 7267         Executive Director                  -7472904.0     ...
# 7268                  President                    545957.0     ...
# 7269             President, CEO                   -319973.0     ...
# 7270                  President                   -113106.0     ...
# 7271         Executive Director                    633197.0     ...
# 7272      President, Evangelist                   -224930.0     ...
# 7273         Executive Director                     22585.0     ...
# 7274         Executive Director                    383617.0     ...
# 7275         Executive Director                   -442987.0     ...
# 7276         Executive Director                     88974.0     ...
# 7277             President, CEO                     60419.0     ...
# 7278            General Manager                   -389309.0     ...
# 7279         Executive Director                    -99772.0     ...
# 7280                  President                  -1489479.0     ...
# 7281         Executive Director                     90687.0     ...
# 7282         Executive Director                    221836.0     ...
# 7283         Executive Director                   -551924.0     ...
# 7284         Executive Director                  -1532796.0     ...
# 7285                  President                    637543.0     ...
# 7286           General Director                   8488396.0     ...
# 7287  President/Artist Director                   6659474.0     ...
# 7288          Managing Director                     49269.0     ...
# 7289              President/CEO                    523627.0     ...
#
#       net_assets  other_revenue  overall_score  payments_to_affiliates  \
# 0        1350382        49634.0          89.75                       0
# 1       14773920       382540.0          85.95                       0
# 2        -770370            0.0          80.96                       0
# 3       11460087       -81726.0          89.94                       0
# 4         723772        32436.0          90.62                       0
# 5       40621685       320916.0          95.14                       0
# 6        3579208       -13057.0          92.22                   33556
# 7        7474607       101537.0          85.81                       0
# 8         808446        10299.0          92.91                       0
# 9        1173256        29857.0          83.02                       0
# 10       3645570        47177.0          88.17                       0
# 11      24114195       718853.0          84.95                       0
# 12        131009        30692.0          80.93                       0
# 13       4553274        16889.0          91.04                       0
# 14       1028525         4345.0          94.27                       0
# 15       5209352       140551.0          86.15                       0
# 16      18192084       248250.0          89.92                       0
# 17         97615        26406.0          77.17                       0
# 18    3679424528     89274989.0          94.70                       0
# 19       2695113       673000.0          84.58                       0
# 20       2226006         2965.0          89.94                       0
# 21     102655210       707769.0          94.69                       0
# 22       2144882       -24976.0          85.26                       0
# 23       2000106       -10572.0          96.20                       0
# 24       2775860       857985.0          95.31                       0
# 25      15706277       603495.0          86.67                       0
# 26       4434900        15833.0          88.66                       0
# 27       -427225         7134.0          83.85                       0
# 28      70125179      2788674.0          92.88                       0
# 29      15582886      4340235.0         100.00                       0
# ...          ...            ...            ...                     ...
# 7260    -3387344      2445416.0          77.96                  562918
# 7261     2913924        88831.0          81.19                       0
# 7262     1816581        26334.0          91.69                       0
# 7263     2107900        17418.0         100.00                       0
# 7264     5040047        61171.0          76.60                       0
# 7265    10455953       -39655.0          93.19                       0
# 7266     3485628        38329.0          91.31                       0
# 7267     5326617         1225.0          89.48                       0
# 7268    17496752        55228.0          93.67                       0
# 7269    18477908       310749.0          83.09                       0
# 7270    17528376       194793.0          90.35                       0
# 7271     4934266       -28267.0          91.92                       0
# 7272     1230381       262523.0          96.46                       0
# 7273     1964408       247262.0          95.02                       0
# 7274     7057009      -130732.0          85.24                       0
# 7275    49761967       481412.0          84.18                       0
# 7276     3676525       121396.0          93.10                   19500
# 7277     3944150       309280.0          78.72                       0
# 7278     5602436        89987.0          84.68                       0
# 7279     6479571       883600.0          91.73                       0
# 7280      680757        38740.0          76.01                       0
# 7281     4253312       208512.0          90.70                       0
# 7282     3959142       -32658.0          83.53                       0
# 7283     3643297        22326.0          90.58                       0
# 7284      276163         4257.0          81.49                       0
# 7285     2721886       680721.0          88.62                       0
# 7286    55444413      -273174.0          88.95                       0
# 7287    39857623       105994.0          88.47                       0
# 7288    23810459      1424559.0          84.42                       0
# 7289     5680445         3083.0          99.43                       0
#
#       program_expenses  state  total_contributions  \
# 0              1440463     WI              1999023
# 1              3912270     HI              3339358
# 2              8157850     NY              8039138
# 3              7018262     NY              9704138
# 4              1148407     CA              1234662
# 5             10059539     CA             12355178
# 6              1024283     GA               536485
# 7              1695556     MD              2170503
# 8              1340579     GA              1473462
# 9              1225020     WA              1574828
# 10             2805884     MD              4595007
# 11             1222660     NY              3051056
# 12             1512485     AL              1044160
# 13             6247620     NY              8562031
# 14             1302535     MI              1063890
# 15              888514     PA               809534
# 16             2712221     AL             10103153
# 17             1760358     AL              1985118
# 18           221903338     MD            122210533
# 19             6220527     IL              5818435
# 20             2244223     NY              3119335
# 21            65695537     PA             23035192
# 22             1371628     MI              1737373
# 23              987277     CO              1453104
# 24             1368684     NY               749944
# 25             2769811     CA              5578134
# 26             2038421     IL              5109815
# 27             2741091     NC              1999290
# 28            14526815     CO             12195279
# 29            18843152     NC              7897648
# ...                ...    ...                  ...
# 7260          12626884     PA              4991553
# 7261           2277805     AZ              3313037
# 7262           1206475     NY               493275
# 7263           1845072     CA              2421960
# 7264           1061825     MO              1153762
# 7265           9322707     WA             12624382
# 7266           2210239     MN              3366606
# 7267          11790812     OH              4190980
# 7268           2762138     KS              4099700
# 7269           1471651     PA              1537133
# 7270          11738367     DC             13164253
# 7271            806385     VA              1687772
# 7272           2753035     TX              2539771
# 7273           1192932     OH               757168
# 7274          14465549     CA             17661025
# 7275           3771676     NE              3984339
# 7276           1992129     MI              1087673
# 7277           1143543     FL              1237457
# 7278           2243579     MN              2018589
# 7279           2729131     CA              2311512
# 7280           3577257     IN              3033105
# 7281           1252608     OH               996204
# 7282           3912483     IL              4858013
# 7283           7726627     VA              7430707
# 7284           1784005     MN              1500347
# 7285           2598730     CA              2991333
# 7286          33939349     CA             34743589
# 7287           3367604     CA              9621671
# 7288          11895492     CA              8836021
# 7289           3664850     PA              3849770
#
#                         org_type  \
# 0         Human and Civil Rights
# 1                      Education
# 2                  International
# 3                      Education
# 4                       Religion
# 5         Human and Civil Rights
# 6          Community Development
# 7                    Environment
# 8                         Health
# 9                      Education
# 10                        Health
# 11     Arts, Culture, Humanities
# 12     Arts, Culture, Humanities
# 13                        Health
# 14                   Environment
# 15                        Health
# 16                   Environment
# 17     Arts, Culture, Humanities
# 18                        Health
# 19                        Health
# 20                        Health
# 21                 International
# 22                Human Services
# 23                 International
# 24                        Health
# 25     Arts, Culture, Humanities
# 26                        Health
# 27                        Health
# 28                       Animals
# 29                Human Services
# ...                          ...
# 7260                      Health
# 7261                    Religion
# 7262   Arts, Culture, Humanities
# 7263                     Animals
# 7264   Arts, Culture, Humanities
# 7265               International
# 7266                 Environment
# 7267                 Environment
# 7268  Research and Public Policy
# 7269   Arts, Culture, Humanities
# 7270                 Environment
# 7271              Human Services
# 7272                    Religion
# 7273                      Health
# 7274              Human Services
# 7275                 Environment
# 7276       Community Development
# 7277                      Health
# 7278   Arts, Culture, Humanities
# 7279              Human Services
# 7280       Community Development
# 7281   Arts, Culture, Humanities
# 7282              Human Services
# 7283                      Health
# 7284                    Religion
# 7285                   Education
# 7286   Arts, Culture, Humanities
# 7287   Arts, Culture, Humanities
# 7288   Arts, Culture, Humanities
# 7289                      Health
#
#                                            org_category org_type_id
# 0                                Advocacy and Education         1.0
# 1                 Early Childhood Programs and Services         2.0
# 2                       Development and Relief Services         3.0
# 3                     Scholarship and Financial Support         2.0
# 4                                  Religious Activities         4.0
# 5                                Advocacy and Education         1.0
# 6                  Housing and Neighborhood Development         5.0
# 7             Environmental Protection and Conservation         6.0
# 8                                      Medical Research         7.0
# 9                     Scholarship and Financial Support         2.0
# 10                 Diseases, Disorders, and Disciplines         7.0
# 11                                              Museums         8.0
# 12                                      Performing Arts         8.0
# 13                 Diseases, Disorders, and Disciplines         7.0
# 14            Environmental Protection and Conservation         6.0
# 15                    Treatment and Prevention Services         7.0
# 16         Botanical Gardens, Parks, and Nature Centers         6.0
# 17                                              Museums         8.0
# 18                 Diseases, Disorders, and Disciplines         7.0
# 19                 Diseases, Disorders, and Disciplines         7.0
# 20                                     Medical Research         7.0
# 21                      Development and Relief Services         3.0
# 22                                    Homeless Services         9.0
# 23                      Development and Relief Services         3.0
# 24                 Diseases, Disorders, and Disciplines         7.0
# 25                                              Museums         8.0
# 26                                     Medical Research         7.0
# 27                                     Medical Research         7.0
# 28                 Animal Rights, Welfare, and Services        10.0
# 29                                    Homeless Services         9.0
# ...                                                 ...         ...
# 7260                                   Medical Research         7.0
# 7261                               Religious Activities         4.0
# 7262                                    Performing Arts         8.0
# 7263               Animal Rights, Welfare, and Services        10.0
# 7264                                            Museums         8.0
# 7265                    Development and Relief Services         3.0
# 7266          Environmental Protection and Conservation         6.0
# 7267       Botanical Gardens, Parks, and Nature Centers         6.0
# 7268                  Social and Public Policy Research        11.0
# 7269  Libraries, Historical Societies and Landmark P...         8.0
# 7270          Environmental Protection and Conservation         6.0
# 7271                                  Homeless Services         9.0
# 7272                   Religious Media and Broadcasting         4.0
# 7273               Diseases, Disorders, and Disciplines         7.0
# 7274                                  Homeless Services         9.0
# 7275       Botanical Gardens, Parks, and Nature Centers         6.0
# 7276               Housing and Neighborhood Development         5.0
# 7277                  Treatment and Prevention Services         7.0
# 7278                      Public Broadcasting and Media         8.0
# 7279                                    Social Services         9.0
# 7280                                        United Ways         5.0
# 7281                                            Museums         8.0
# 7282   Food Banks, Food Pantries, and Food Distribution         9.0
# 7283                  Treatment and Prevention Services         7.0
# 7284                               Religious Activities         4.0
# 7285              Youth Education Programs and Services         2.0
# 7286                                    Performing Arts         8.0
# 7287                                    Performing Arts         8.0
# 7288                                    Performing Arts         8.0
# 7289                  Treatment and Prevention Services         7.0
#
# [7290 rows x 22 columns]

# %%
df.head()

# %%
df.info()

# %%
df.describe()
# Out:
#        accountability_score  administrative_expenses  comp_leader_income  \
# count           8190.000000             8.190000e+03        7.290000e+03
# mean              90.441758             1.235162e+06        1.659498e+05
# std                9.892188             5.773610e+06        1.298927e+05
# min               24.000000             7.230000e+02        1.000000e+00
# 25%               88.000000             1.824298e+05        9.155775e+04
# 50%               93.000000             3.543450e+05        1.311865e+05
# 75%               97.000000             8.078158e+05        1.977418e+05
# max              100.000000             2.569202e+08        2.013535e+06
#
#        comp_leader_expense_pct  excess_or_deficit_for_year  financial_score  \
# count              7290.000000                8.190000e+03      8190.000000
# mean                  3.543462                8.754504e+05        85.761328
# std                   2.384256                1.129444e+07        10.290726
# min                   0.000000               -2.691435e+08         0.000000
# 25%                   1.610000               -2.310360e+05        80.920000
# 50%                   3.150000                6.372200e+04        87.355000
# 75%                   5.120000                6.015620e+05        92.500000
# max                   9.990000                4.531299e+08       100.000000
#
#        fundraising_expenses    net_assets  other_revenue  overall_score  \
# count          8.190000e+03  8.190000e+03   8.190000e+03    8190.000000
# mean           1.022347e+06  3.043019e+07   1.127527e+06      86.609466
# std            5.893024e+06  1.668934e+08   7.452022e+06       8.351857
# min            0.000000e+00 -1.350503e+07  -1.391081e+07      14.480000
# 25%            1.491075e+05  1.956616e+06   1.006200e+04      83.150000
# 50%            3.077695e+05  5.364198e+06   1.082565e+05      88.170000
# 75%            6.762818e+05  1.548521e+07   4.759095e+05      91.877500
# max            3.377669e+08  7.551342e+09   3.903250e+08     100.000000
#
#        payments_to_affiliates  program_expenses  total_contributions  \
# count            8.190000e+03      8.190000e+03         8.190000e+03
# mean             2.041822e+04      1.277029e+07         1.228778e+07
# std              2.671293e+05      6.171554e+07         5.791442e+07
# min             -4.101700e+04      5.928000e+03         2.744400e+04
# 25%              0.000000e+00      1.588696e+06         1.611900e+06
# 50%              0.000000e+00      3.009392e+06         3.085724e+06
# 75%              0.000000e+00      7.525806e+06         7.285939e+06
# max              1.679144e+07      2.499301e+09         2.379130e+09
#
#        org_type_id
# count  8190.000000
# mean      6.685470
# std       2.727851
# min       1.000000
# 25%       5.000000
# 50%       8.000000
# 75%       9.000000
# max      11.000000

# %% [markdown]
# Add dummy variables for organization type.

# %%
org_type_dummies = pd.get_dummies(df2.org_type)
df2 = pd.concat([df2, org_type_dummies], axis = 1, join = 'outer')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-bb089aefa02a> in <module>()
# ----> 1 org_type_dummies = pd.get_dummies(df2.org_type)
#       2 df2 = pd.concat([df2, org_type_dummies], axis = 1, join = 'outer')
#
# NameError: name 'df2' is not defined

# %% [markdown]
# Drop non-numerical variables from the dataframe.

# %%
df2.drop(['charity_name', 'charity_url', 
          'city', 'cn_advisory', 
          'state', 'org_type',
          'org_category', 'comp_leader_title'], 
         axis = 1, inplace = True)
df2.head()

# %% [markdown]
# ## **Predicting compensation leader income for US charities**

# %% [markdown]
# ### **Train Test Split**

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# All numerical features including org type dummy variables are included (with the exception of compensation leader expense percent).

# %%
feature_names = ['accountability_score', 'financial_score',
                 'overall_score', 'administrative_expenses',
                 'excess_or_deficit_for_year', 'fundraising_expenses',
                 'net_assets', 'other_revenue',
                 'payments_to_affiliates', 'Animals',
                 'Arts, Culture, Humanities', 'Community Development',
                 'Education', 'Environment',
                 'Health', 'Human Services',
                 'Human and Civil Rights', 'International',
                 'Religion', 'Research and Public Policy']
X = df2[feature_names]
y = df2['comp_leader_income']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 101)

# %% [markdown]
# ### **Standard Scaler**

# %% [markdown]
# First use a standard scaler to level all features in the model.

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# Create a dataframe to see scaled features.

# %%
df_scaled_features = pd.DataFrame(X_train_scaled, columns = X.columns)
df_scaled_features2 = pd.DataFrame(X_test_scaled, columns = X.columns)
df_scaled_features = pd.concat([df_scaled_features, df_scaled_features2], axis=1, join = 'outer')
df_scaled_features.head()

# %% [markdown]
# ### **Linear Regression**
#
# #### *Will simple linear regression allow for an accurate model to predict compensation leader income?*

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# Instantiate LinearRegression() and fit our data to a new model.

# %%
linreg = LinearRegression()
linreg.fit(X_train_scaled, y_train)
y_pred = linreg.predict(X_test_scaled).round().astype(int)

# %% [markdown]
# *Is there a linear relationship between our test values and our predicted values?*

# %%
ax = sns.jointplot(x = y_test, y = y_pred, 
                   kind = 'reg', size = 6, ratio = 6, 
                   joint_kws={'color': 'skyblue'});
ax.set_axis_labels('Y Test', 'Predicted Y')
regline = ax.ax_joint.get_lines()[0]
regline.set_color('red')

# %% [markdown]
# *What is the distribution of our prediction errors?*

# %%
plt.figure(figsize = (9, 5))
ax = sns.distplot((y_test - y_pred), bins = 25)
ax.xaxis.set_tick_params(which = 'both', rotation = 45)

# %%
print('Simple Linear Regression Coefficients\nPolynomial Degree 1\nAlpha = 0')
print('Intercept:', linreg.intercept_.round(4))
print('Total Non-Zero Coefficients: {}\n'.format(len(linreg.coef_.round(4))))
cdf = pd.DataFrame(linreg.coef_.round(4), X.columns, columns = ['Coefficient'])
print(cdf)

# %% [markdown]
# *What is the average magnitude of the coefficients in this model?*

# %%
abs(cdf['Coefficient']).mean().round(4)

# %% [markdown]
# *Which coefficient in this model has the strongest magnitude?*

# %%
cdf[cdf['Coefficient'] == abs(cdf['Coefficient']).max()]

# %%
print('Train R^2:', linreg.score(X_train_scaled, y_train).round(4))
print('Test  R^2:', linreg.score(X_test_scaled, y_test).round(4))
print('MAE:      ', metrics.mean_absolute_error(y_test, y_pred).round(4))
print('MSE:      ', metrics.mean_squared_error(y_test, y_pred).round(4))
print('RMSE:     ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)).round(4))

# %% [markdown]
# At 0.175, our Test R^2 score is very low.
#
# *Will changing the polynomial degree allow for an increase in our model score?*

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
n = [1, 2, 3]
i = 0
for n in n:
    poly = PolynomialFeatures(degree = n)
    X_poly_train = poly.fit_transform(X_train_scaled)
    linreg = linreg.fit(X_poly_train, y_train)
    y_pred = linreg.predict(poly.fit_transform(X_test_scaled))
#     print('Simple Linear Regression, Polynomial Degree {} | coeff (w):\n{}'.format(n, linreg.coef_.round(4)))
#     print('Simple Linear Regression, Polynomial Degree {} |  intercept (b): {:.4f}'.format(n, linreg.intercept_.round(4)))
    print('Simple Linear Regression, Polynomial Degree {} | R^2 Train: {:.4f}'.format(n, linreg.score(X_poly_train, y_train).round(4)))
    print('Simple Linear Regression, Polynomial Degree {} | R^2  Test: {:.4f}'.format(n, linreg.score(poly.fit_transform(X_test_scaled), y_test).round(4)))
    i+=1

# %% [markdown]
# Using a simple linear regression, polynomial degree 1 produces our best Test R^2 score at 0.1754.
#
# As this value is quite low, let's see if another type of linear model will allow for an increase.

# %% [markdown]
# ### **Ridge Regression**
#
# #### *Will a ridge regression allow for an accurate model to predict compensation leader income?*

# %%
from sklearn.linear_model import Ridge

# %% [markdown]
# Let's see how our choice of alpha effects our training and testing R^2 scores.
#
# Instantiate Ridge() and fit our data to a list of choices for alpha, printing our R^2 scores for each model fit.

# %%
print('Ridge regression: effect of alpha regularization parameter \
with polynomial degree 1\n')
r2_train_dic = {}
r2_test_dic = {}
for this_alpha in [0, 1, 10, 20, 50, 100, 200, 
                   250, 500, 750, 1000, 1050, 
                   1100, 1200, 1300, 1400, 2000]:
    linridge = Ridge(alpha = this_alpha)
    linridge.fit(X_train_scaled, y_train)
    r2_train = linridge.score(X_train_scaled, y_train)
    r2_train_dic[this_alpha] = linridge.score(X_train_scaled, y_train)
    r2_test = linridge.score(X_test_scaled, y_test)
    r2_test_dic[this_alpha] = linridge.score(X_test_scaled, y_test)
    num_coeff = 0
    n = 0
    for coefficient in linridge.coef_:
        if abs(linridge.coef_[n]) > 1.0:
            num_coeff+=1
            n+=1
        else:
            n+=1
    print('Alpha = {}\nnum abs(coeff) > 1.0: {}, \
    Train R^2: {:.4f}, Test R^2: {:.4f}\n'
         .format(this_alpha, num_coeff, r2_train, r2_test))

# %% [markdown]
# Almost every choice for alpha above produced an R^2 score over 0.174 (highest score for simple linear regression).
#
# These results suggest that a model other than simple linear regression will be more accurate.

# %% [markdown]
# *With a ridge regression of polynomial degree 1, how does our choice of alpha effect training and testing R^2 scores?*

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1,
                         figsize = (9, 8))
axes[0].plot(r2_train_dic.keys(), r2_train_dic.values())
axes[0].set_xlabel('Alpha')
axes[0].set_ylabel('R^2 Training Score')
axes[0].set_title('Ridge Regression, Polynomial Degree 1\n \
R^2 Training Score by Alpha Regularization Parameter')
axes[1].plot(r2_test_dic.keys(), r2_test_dic.values())
axes[1].set_xlabel('Alpha')
axes[1].set_ylabel('R^2 Testing Score')
axes[1].set_title('Ridge Regression, Polynomial Degree 1\n \
R^2 Testing Score by Alpha Regularization Parameter')

plt.tight_layout()

# %% [markdown]
# The line graph above suggests that an increase alpha will lead to an increase in Test R^2, though this return will diminish within an increase of just 0.02.

# %% [markdown]
# Let's instantiate a new ridge regression, choosing the alpha value that produced the highest test R^2 score.

# %%
linridge = Ridge(alpha = 1100)
linridge.fit(X_train_scaled, y_train)
y_pred = linridge.predict(X_test_scaled)

# %% [markdown]
# *Is there a linear relationship between our test values and our predicted values?*

# %%
ax = sns.jointplot(x = y_test, y = y_pred, 
                   kind = 'reg', size = 6, ratio = 6, 
                   joint_kws={'color': 'skyblue'});
ax.set_axis_labels('Y Test', 'Predicted Y')
regline = ax.ax_joint.get_lines()[0]
regline.set_color('red')

# %% [markdown]
# *What is the distribution of our prediction errors?*

# %%
plt.figure(figsize = (9, 5))
ax = sns.distplot((y_test - y_pred), bins = 25)
ax.xaxis.set_tick_params(which = 'both', rotation = 45)

# %%
print('Ridge Regression Coefficients\nPolynomial Degree 1\nAlpha = 1100')
print('Intercept:', linridge.intercept_.round(4))
print('Total Non-Zero Coefficients: {}\n'.format(len(linridge.coef_.round(4))))
cdf = pd.DataFrame(linridge.coef_.round(4), X.columns, columns = ['Coefficient'])
print(cdf)

# %% [markdown]
# *What is the average magnitude of the coefficients in this model?*

# %%
abs(cdf['Coefficient']).mean().round(4)

# %% [markdown]
# *Which coefficient in this model has the strongest magnitude?*

# %%
cdf[cdf['Coefficient'] == abs(cdf['Coefficient']).max()]

# %%
print('Train R^2:', linridge.score(X_train_scaled, y_train).round(4))
print('Test  R^2:', linridge.score(X_test_scaled, y_test).round(4))
print('MAE:      ', metrics.mean_absolute_error(y_test, y_pred).round(4))
print('MSE:      ', metrics.mean_squared_error(y_test, y_pred).round(4))
print('RMSE:     ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)).round(4))

# %% [markdown]
# Using ridge regression with an optimized alpha, our test R^2 of 0.1939 outperforms our previous best of 0.175 (highest score for simple linear regression).
#
# So far, a ridge regression at polynomial degree 1 is the top performer.

# %% [markdown]
# Though a polynomial degree of 1 had the highest test R^2 score for simple linear regression, this may not be the case using a different linear model.
#
# Let's see if a ridge regression using another polynomial degree will allow for an even better test R^2 score.
#
# Instantiate Ridge() and fit our data to a list of choices for the polynomial degree, printing our R^2 scores for each model fit.

# %%
n = [1, 2, 3]
i = 0
for n in n:
    poly = PolynomialFeatures(degree = n)
    X_poly_train = poly.fit_transform(X_train_scaled)
    linridge = Ridge(alpha = 1100)
    linridge.fit(X_poly_train, y_train)
    y_pred = linridge.predict(poly.fit_transform(X_test_scaled))
#     print('Ridge Regression, Polynomial Degree{} | coeff (w):\n{}'.format(n, linridge.coef_.round(4)))
#     print('Ridge Regression, Polynomial Degree{} |  intercept (b): {:.4f}'.format(n, linridge.intercept_.round(4)))
    print('Ridge Regression, Polynomial Degree{} | R^2 Train: {:.4f}'.format(n, linridge.score(X_poly_train, y_train).round(4)))
    print('Ridge Regression, Polynomial Degree{} | R^2  Test: {:.4f}'.format(n, linridge.score(poly.fit_transform(X_test_scaled), y_test).round(4)))
    i+=1

# %% [markdown]
# The ridge regression with a polynomial degree of 2 produced the highest test R^2 score, and the exponential model performed the worst.
#
# Let's repeat our alpha optimization loop using a quadratic fit for our polynomial degree.

# %% [markdown]
# With a ridge regression of polynomial degree 2, how does our choice of alpha effect training and testing R^2 scores

# %%
print('Ridge regression: effect of alpha regularization parameter \
with polynomial degree 2\n')
r2_train_dic = {}
r2_test_dic = {}
for this_alpha in [0, 1, 10, 20, 50, 100, 200, 250, 500, 
                   750, 1000, 1050, 1100, 1200, 1300, 1400,
                   1900, 1950, 1955, 1956, 1957, 1958, 1959, 
                   1960, 1965, 1975, 2000]:
    poly = PolynomialFeatures(degree = 2)
    X_poly_train = poly.fit_transform(X_train_scaled)
    linridge = Ridge(alpha = this_alpha)
    linridge.fit(X_poly_train, y_train)
    r2_train = linridge.score(X_poly_train, y_train).round(4)
    r2_train_dic[this_alpha] = linridge.score(X_poly_train, y_train).round(4)
    r2_test = linridge.score(poly.fit_transform(X_test_scaled), y_test).round(4)
    r2_test_dic[this_alpha] = linridge.score(poly.fit_transform(X_test_scaled), y_test).round(4)
    num_coeff = 0
    n = 0
    for coefficient in linridge.coef_:
        if abs(linridge.coef_[n]) > 1.0:
            num_coeff+=1
            n+=1
        else:
            n+=1
    print('Alpha = {}\nnum abs(coeff) > 1.0: {}, \
    Train R^2: {:.4f}, Test R^2: {:.4f}\n'
         .format(this_alpha, num_coeff, r2_train, r2_test))

# %% [markdown]
# Optimizing alpha with a quadratic fit, produces the highest test R^2 scores we've seen yet.
#
# The highest test R^2 score of 0.3059, is much higher than our previous best score of 0.1939.

# %% [markdown]
# *With a ridge regression of polynomial degree 2, how does our choice of alpha effect training and testing R^2 scores?*

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1,
                         figsize = (9, 8))
axes[0].plot(r2_train_dic.keys(), r2_train_dic.values())
axes[0].set_xlabel('Alpha')
axes[0].set_ylabel('R^2 Training Score')
axes[0].set_title('Ridge Regression, Polynomial Degree 2\n \
R^2 Training Score by Alpha Regularization Parameter')
axes[1].plot(r2_test_dic.keys(), r2_test_dic.values())
axes[1].set_xlabel('Alpha')
axes[1].set_ylabel('R^2 Testing Score')
axes[1].set_title('Ridge Regression, Polynomial Degree 2\n \
R^2 Testing Score by Alpha Regularization Parameter')

plt.tight_layout()

# %% [markdown]
# The line graph above suggests that an increase alpha will bring the test R^2 score above 0, though this return will diminish soon after the values become positive.

# %% [markdown]
# Let's instantiate a new ridge regression with a quadratic fit, choosing the alpha value that produced the highest test R^2 score.

# %%
poly = PolynomialFeatures(degree = 2)
X_poly_train = poly.fit_transform(X_train_scaled)
linridge = Ridge(alpha = 1960)
linridge.fit(X_poly_train, y_train)
y_pred = linridge.predict(poly.fit_transform(X_test_scaled))

# %% [markdown]
# *Is there a linear relationship between our test values and our predicted values?*

# %%
ax = sns.jointplot(x = y_test, y = y_pred, 
                   kind = 'reg', size = 6, ratio = 6, 
                   joint_kws={'color': 'skyblue'});
ax.set_axis_labels('Y Test', 'Predicted Y')
regline = ax.ax_joint.get_lines()[0]
regline.set_color('red')

# %% [markdown]
# *What is the distribution of our prediction errors?*

# %%
plt.figure(figsize = (9, 5))
ax = sns.distplot((y_test - y_pred), bins = 25)
ax.xaxis.set_tick_params(which = 'both', rotation = 45)

# %% [markdown]
# Let's create a new dictionary to see all non-zero coefficients in our current model.

# %%
coeff_dic = {}
n = 0
for coef_ in linridge.coef_:
    if abs(linridge.coef_[n].round(4)) != 0:
        coeff_dic[poly.get_feature_names(feature_names)[n]] = linridge.coef_[n].round(4)
        n+=1
    else:
        n+=1

# %%
import json

# %%
print('Ridge Regression Coefficients\nPolynomial Degree 2\nAlpha = 1960')
print('Intercept:', linridge.intercept_.round(4))
print('Total Non-Zero Coefficients: {}\n'.format(len(coeff_dic)))
print(json.dumps(coeff_dic, indent = 1))

# %% [markdown]
# *What is the average magnitude of the coefficients in this model?*

# %%
abs(linridge.coef_).mean().round(4)

# %% [markdown]
# *Which coefficient in this model has the strongest magnitude?*

# %%
for coefficient, correlation in coeff_dic.items():
    if correlation == abs(linridge.coef_).max().round(4):
        print('{}: {}'.format(coefficient, correlation))

# %%
print('Train R^2:', linridge.score(X_poly_train, y_train).round(4))
print('Test  R^2:', linridge.score(poly.fit_transform(X_test_scaled), y_test).round(4))
print('MAE:      ', metrics.mean_absolute_error(y_test, y_pred).round(4))
print('MSE:      ', metrics.mean_squared_error(y_test, y_pred).round(4))
print('RMSE:     ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)).round(4))

# %% [markdown]
# In fitting our data to a quadratic model with a new optimized alpha, our test R^2 of 0.3059 outperforms our previous best test R^2 score of 0.1939 by a large margin.
#
# A ridge regression at polynomial degree 2 is now our top performer.
#
# Let's see if a lasso regression will allow for an even better test R^2 score than a ridge regression.

# %% [markdown]
# ### **Lasso Regression**
#
# ##### *Will a lasso regression allow for an accurate model to predict compensation leader income?*

# %%
from sklearn.linear_model import Lasso

# %% [markdown]
# Let's see how our choice of alpha effects our training and testing R^2 scores.
#
# Instantiate Lasso() and fit our data to a list of choices for alpha, printing our R^2 scores for each model fit.

# %%
print('Lasso regression: effect of alpha regularization parameter \
with polynomial degree 1\n')
r2_train_dic = {}
r2_test_dic = {}
for this_alpha in [0, 1, 10, 20, 50, 75, 100, 200, 250, 
                   500, 750, 1000, 2000, 3000, 4000, 5000]:
    linlasso = Lasso(alpha = this_alpha)
    linlasso.fit(X_train_scaled, y_train)
    r2_train = linlasso.score(X_train_scaled, y_train)
    r2_train_dic[this_alpha] = linlasso.score(X_train_scaled, y_train)
    r2_test = linlasso.score(X_test_scaled, y_test)
    r2_test_dic[this_alpha] = linlasso.score(X_test_scaled, y_test)
    num_coeff = 0
    n = 0   
    for coefficient in linlasso.coef_:
        if abs(linlasso.coef_[n]) > 1.0:
            num_coeff+=1
            n+=1
        else:
            n+=1
    print('Alpha = {}\nnum abs(coeff) > 1.0: {}, \
    Train R^2: {:.4f}, Test R^2: {:.4f}\n'
         .format(this_alpha, num_coeff, r2_train, r2_test))

# %% [markdown]
# Starting with a polynomial degree of 1 while varying our choice for alpha, test R^2 scores are hovering at our previous high for simple linear regression of 0.174.
#
# We'll need to adjust the polynomial degree to see if a lasso regression can compete with a ridge regression to predict compensation leader income.

# %% [markdown]
# *With a lasso regression of polynomial degree 1, how does our choice of alpha effect training and testing R^2 scores?*

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1,
                         figsize = (9, 8))
axes[0].plot(r2_train_dic.keys(), r2_train_dic.values())
axes[0].set_xlabel('Alpha')
axes[0].set_ylabel('R^2 Training Score')
axes[0].set_title('Lasso Regression, Polynomial Degree 1\n \
R^2 Training Score by Alpha Regularization Parameter')
axes[1].plot(r2_test_dic.keys(), r2_test_dic.values())
axes[1].set_xlabel('Alpha')
axes[1].set_ylabel('R^2 Testing Score')
axes[1].set_title('Lasso Regression, Polynomial Degree 1\n \
R^2 Testing Score by Alpha Regularization Parameter')

plt.tight_layout()

# %% [markdown]
# The line graph above suggests that an increase alpha will not increase the test R^2 score at all.
#
# Since an alpha choice of 0.174 is far below scores we've gotten from other models, a lasso regression with a polynomial degree of 1 should not be used.

# %%
n = [1, 2, 3, 4]
i = 0
for n in n:
    poly = PolynomialFeatures(degree = n)
    X_poly_train = poly.fit_transform(X_train_scaled)
    linlasso = Lasso(alpha = 1960)
    linlasso.fit(X_poly_train, y_train)
    y_pred = linlasso.predict(poly.fit_transform(X_test_scaled))
#     print('Lasso Regression, Polynomial Degree {} | coeff (w):\n{}'.format(n, linlasso.coef_.round(4)))
#     print('Lasso Regression, Polynomial Degree {} |  intercept (b): {:.4f}'.format(n, linlasso.intercept_.round(4)))
    print('Lasso Regression, Polynomial Degree {} | R^2 Train: {:.4f}'.format(n, linlasso.score(X_poly_train, y_train).round(4)))
    print('Lasso Regression, Polynomial Degree {} | R^2  Test: {:.4f}'.format(n, linlasso.score(poly.fit_transform(X_test_scaled), y_test).round(4)))
    i+=1

# %% [markdown]
# The lasso regression with a polynomial degree of 3 produced the highest test R^2 score at 0.5813, and the quadratic model performed second best at 0.2775.
#
# This R^2 score beats our previous best of 0.3059 by a large margin.
#
# Let's repeat our alpha optimization loop first using a quadratic fit for our polynomial degree, and then the exponntial fit to compare.

# %% [markdown]
# *With a lasso regression of polynomial degree 2, how does our choice of alpha effect training and testing R^2 scores?*

# %%
print('Lasso regression: effect of alpha regularization parameter \
with polynomial degree 2\n')
r2_train_dic = {}
r2_test_dic = {}
for this_alpha in [0, 1, 10, 20, 50, 100, 200, 250, 500, 750, 1000, 
                   1050, 1100, 1200, 1300, 1400, 1900, 1950, 2000, 
                   2100, 2200, 2300, 2400, 2500, 2600, 2700, 2800, 
                   2900, 3000, 3100, 3200, 3210, 3120, 3230, 3240, 
                   3250, 3260, 3270, 3280, 3290, 3300, 3350, 3400, 
                   3500, 3600, 3700, 3800, 3900, 4000]:
    poly = PolynomialFeatures(degree = 2)
    X_poly_train = poly.fit_transform(X_train_scaled)
    linlasso = Lasso(alpha = this_alpha)
    linlasso.fit(X_poly_train, y_train)
    r2_train = linlasso.score(X_poly_train, y_train).round(4)
    r2_train_dic[this_alpha] = linlasso.score(X_poly_train, y_train).round(4)
    r2_test = linlasso.score(poly.fit_transform(X_test_scaled), y_test).round(4)
    r2_test_dic[this_alpha] = linlasso.score(poly.fit_transform(X_test_scaled), y_test).round(4)
    num_coeff = 0
    n = 0
    for coefficient in linlasso.coef_:
        if abs(linlasso.coef_[n]) > 1.0:
            num_coeff+=1
            n+=1
        else:
            n+=1
    print('Alpha = {}\nnum abs(coeff) > 1.0: {}, \
    Train R^2: {:.4f}, Test R^2: {:.4f}\n'
         .format(this_alpha, num_coeff, r2_train, r2_test))

# %% [markdown]
# *With a lasso regression of polynomial degree 2, how does our choice of alpha effect training and testing R^2 scores?*

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1,
                         figsize = (9, 8))
axes[0].plot(r2_train_dic.keys(), r2_train_dic.values())
axes[0].set_xlabel('Alpha')
axes[0].set_ylabel('R^2 Training Score')
axes[0].set_title('Lasso Regression, Polynomial Degree 2\n \
R^2 Training Score by Alpha Regularization Parameter')
axes[1].plot(r2_test_dic.keys(), r2_test_dic.values())
axes[1].set_xlabel('Alpha')
axes[1].set_ylabel('R^2 Testing Score')
axes[1].set_title('Lasso Regression, Polynomial Degree 2\n \
R^2 Training Score by Alpha Regularization Parameter')

plt.tight_layout()

# %% [markdown]
# The line graph above suggests that an increase alpha will bring the test R^2 score above 0 with a steady slope.
#
# The test R^2 score will continue to steadily increasing until an alpha value of 3,240 is reached.

# %%
poly = PolynomialFeatures(degree = 2)
X_poly_train = poly.fit_transform(X_train_scaled)
linlasso = Lasso(alpha = 3240)
linlasso.fit(X_poly_train, y_train)
y_pred = linlasso.predict(poly.fit_transform(X_test_scaled))

# %% [markdown]
# *Is there a linear relationship between our test values and our predicted values?*

# %%
ax = sns.jointplot(x = y_test, y = y_pred, 
                   kind = 'reg', size = 6, ratio = 6, 
                   joint_kws={'color': 'skyblue'});
ax.set_axis_labels('Y Test', 'Predicted Y')
regline = ax.ax_joint.get_lines()[0]
regline.set_color('red')

# %% [markdown]
# *What is the distribution of our prediction errors?*

# %%
plt.figure(figsize = (9, 5))
ax = sns.distplot((y_test - y_pred), bins = 25)
ax.xaxis.set_tick_params(which = 'both', rotation = 45)

# %% [markdown]
# Let's create a new dictionary to see all non-zero coefficients in our current model.

# %%
coeff_dic = {}
n = 0
for coef_ in linlasso.coef_:
    if abs(linlasso.coef_[n].round(4)) != 0:
        coeff_dic[poly.get_feature_names(feature_names)[n]] = linlasso.coef_[n].round(4)
        n+=1
    else:
        n+=1

# %%
print('Lasso Regression Coefficients\nPolynomial Degree 2\nAlpha = 3240')
print('Intercept:', linlasso.intercept_.round(4))
print('Total Non-Zero Coefficients: {}\n'.format(len(coeff_dic)))
print(json.dumps(coeff_dic, indent = 1))

# %% [markdown]
# *What is the average magnitude of the coefficients in this model?*

# %%
abs(linlasso.coef_).mean().round(4)

# %% [markdown]
# *Which coefficient in this model has the strongest magnitude?*

# %%
for coefficient, correlation in coeff_dic.items():
    if correlation == abs(linlasso.coef_).max().round(4):
        print('{}: {}'.format(coefficient, correlation))

# %%
print('Train R^2:', linlasso.score(X_poly_train, y_train).round(4))
print('Test  R^2:', linlasso.score(poly.fit_transform(X_test_scaled), y_test).round(4))
print('MAE:      ', metrics.mean_absolute_error(y_test, y_pred).round(4))
print('MSE:      ', metrics.mean_squared_error(y_test, y_pred).round(4))
print('RMSE:     ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)).round(4))

# %% [markdown]
# Now let's see how an exponential model compares to a quadratic model.
#
# If our test R^2 scores are consistent with our previous model projections, then the exponential model should perform the best.

# %% [markdown]
# *With a lasso regression of polynomial degree 3, how does our choice of alpha effect training and testing R^2 scores?*

# %%
print('Lasso regression: effect of alpha regularization parameter \
with polynomial degree 3\n')
r2_train_dic = {}
r2_test_dic = {}
for this_alpha in [0, 1, 10, 20, 50, 100, 200, 250, 500, 750, 1000, 
                   1050, 1100, 1200, 1300, 1400, 1900, 1950, 2000, 
                   2100, 2200, 2300, 2400, 2500, 2600, 2700, 2800, 
                   2900, 3000, 3100, 3200, 3300, 3400, 3450, 3460, 
                   3470, 3480, 3490, 3500, 3550, 3600, 3700, 3800, 
                   3900, 4000]:
    poly = PolynomialFeatures(degree = 3)
    X_poly_train = poly.fit_transform(X_train_scaled)
    linlasso = Lasso(alpha = this_alpha)
    linlasso.fit(X_poly_train, y_train)
    r2_train = linlasso.score(X_poly_train, y_train).round(4)
    r2_train_dic[this_alpha] = linlasso.score(X_poly_train, y_train).round(4)
    r2_test = linlasso.score(poly.fit_transform(X_test_scaled), y_test).round(4)
    r2_test_dic[this_alpha] = linlasso.score(poly.fit_transform(X_test_scaled), y_test).round(4)
    num_coeff = 0
    n = 0
    for coefficient in linlasso.coef_:
        if abs(linlasso.coef_[n]) > 1.0:
            num_coeff+=1
            n+=1
        else:
            n+=1
    print('Alpha = {}\nnum abs(coeff) > 1.0: {}, \
    Train R^2: {:.4f}, Test R^2: {:.4f}\n'
         .format(this_alpha, num_coeff, r2_train, r2_test))

# %% [markdown]
# *With a lasso regression of polynomial degree 3, how does our choice of alpha effect training and testing R^2 scores?*

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1,
                         figsize = (9, 8))
axes[0].plot(r2_train_dic.keys(), r2_train_dic.values())
axes[0].set_xlabel('Alpha')
axes[0].set_ylabel('R^2 Training Score')
axes[0].set_title('Lasso Regression, Polynomial Degree 3\n \
R^2 Training Score by Alpha Regularization Parameter')
axes[1].plot(r2_test_dic.keys(), r2_test_dic.values())
axes[1].set_xlabel('Alpha')
axes[1].set_ylabel('R^2 Testing Score')
axes[1].set_title('Lasso Regression, Polynomial Degree 3\n \
R^2 Testing Score by Alpha Regularization Parameter')

plt.tight_layout()

# %% [markdown]
# The line graph above suggests that an increase alpha will bring the test R^2 score above 0 with a sharp slope.
#
# The test R^2 score will continue to steadily increase until an alpha value of 3,490 is reached.

# %%
poly = PolynomialFeatures(degree = 3)
X_poly_train = poly.fit_transform(X_train_scaled)
linlasso = Lasso(alpha = 3490)
linlasso.fit(X_poly_train, y_train)
y_pred = linlasso.predict(poly.fit_transform(X_test_scaled))

# %% [markdown]
# *Is there a linear relationship between our test values and our predicted values?*

# %%
ax = sns.jointplot(x = y_test, y = y_pred, 
                   kind = 'reg', size = 6, ratio = 6, 
                   joint_kws={'color': 'skyblue'});
ax.set_axis_labels('Y Test', 'Predicted Y')
regline = ax.ax_joint.get_lines()[0]
regline.set_color('red')

# %% [markdown]
# *What is the distribution of our prediction errors?*

# %%
plt.figure(figsize = (9, 5))
ax = sns.distplot((y_test - y_pred), bins = 25)
ax.xaxis.set_tick_params(which = 'both', rotation = 45)

# %% [markdown]
# Let's create a new dictionary to see all non-zero coefficients in our current model.

# %%
coeff_dic = {}
n = 0
for coef_ in linlasso.coef_:
    if abs(linlasso.coef_[n].round(4)) != 0:
        coeff_dic[poly.get_feature_names(feature_names)[n]] = linlasso.coef_[n].round(4)
        n+=1
    else:
        n+=1

# %%
print('Lasso Regression Coefficients\nPolynomial Degree 3\nAlpha = 3490')
print('Intercept:', linlasso.intercept_.round(4))
print('Total Non-Zero Coefficients: {}\n'.format(len(coeff_dic)))
print(json.dumps(coeff_dic, indent = 1))

# %% [markdown]
# *What is the average magnitude of the coefficients in this model?*

# %%
abs(linlasso.coef_).mean().round(4)

# %% [markdown]
# *Which coefficient in this model has the strongest magnitude?*

# %%
for coefficient, correlation in coeff_dic.items():
    if correlation == abs(linlasso.coef_).max().round(4):
        print('{}: {}'.format(coefficient, correlation))

# %%
print('Train R^2:', linlasso.score(X_poly_train, y_train).round(4))
print('Test  R^2:', linlasso.score(poly.fit_transform(X_test_scaled), y_test).round(4))
print('MAE:      ', metrics.mean_absolute_error(y_test, y_pred).round(4))
print('MSE:      ', metrics.mean_squared_error(y_test, y_pred).round(4))
print('RMSE:     ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)).round(4))

# %% [markdown]
# The exponential lasso regression with an optimized alpha has produced the highest test R^2 score yet!
#
# This test R^2 score is 0.4632, compared to the quadratic lasso regression score of 0.4433.
